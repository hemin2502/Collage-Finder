# %% [markdown]
# # Project 2 : Rock Papper Scissor

# %%
rock = "rock"
papper = "papper"
scissor = "scissor"
print("_"*85 + "\n")
while True:

    user1 = input("player1 please choose any one bettwen Rock, Papper and Scissor : ")
    user2 = input("player2 please choose any one bettwen Rock, Papper and Scissor : ")
    print("\n"+"*"*85)
    if(user1 == rock) and (user2 == rock):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: tie ..... please try again")
    elif(user1 == rock) and (user2 == papper):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player2")
    elif(user1 == rock) and (user2 == scissor):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player1")
    elif(user1 == papper) and (user2 == rock):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player1")
    elif(user1 == papper) and (user2 == papper):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: tie ..... please try again")
    elif(user1 == papper) and (user2 == scissor):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player2")
    elif(user1 == scissor) and (user2 == rock):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player2")
    elif(user1 == scissor) and (user2 == papper):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: win player1")
    elif(user1 == scissor) and (user2 == scissor):
        print(f"Player1 choose {user1} and Player2 choose {user2}")
        print("result: tie ..... please try again")
    else:
        break
    print("_"*85 + "\n")
print("result: Please choose any one out of rock, papper and scissor")
# Out:
# _____________________________________________________________________________________
#
# player1 please choose any one bettwen Rock, Papper and Scissor : papper
# player2 please choose any one bettwen Rock, Papper and Scissor : rock
#
# *************************************************************************************
# Player1 choose papper and Player2 choose rock
# result: win player1
# _____________________________________________________________________________________
#
# player1 please choose any one bettwen Rock, Papper and Scissor : rock
# player2 please choose any one bettwen Rock, Papper and Scissor : scissor
#
# *************************************************************************************
# Player1 choose rock and Player2 choose scissor
# result: win player1
# _____________________________________________________________________________________
#
# player1 please choose any one bettwen Rock, Papper and Scissor : sdshd
# ...
